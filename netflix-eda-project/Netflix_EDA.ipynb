# %%
import pandas as pd

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
missing_percent=(df.isnull().sum()/len(df))*100
missing_percent.sort_values(ascending=False)
# Out:
# director        29.908028
# country          9.435676
# cast             9.367549
# date_added       0.113546
# rating           0.045418
# duration         0.034064
# show_id          0.000000
# type             0.000000
# title            0.000000
# release_year     0.000000
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
missing=df.isnull().sum()
missing[missing > 0]
# Out:
# director      2634
# cast           825
# country        831
# date_added      10
# rating           4
# duration         3
# dtype: int64

# %%
df[df['director'].isnull()][['title', 'director']].head(10)
# Out:
#                                   title director
# 1                         Blood & Water      NaN
# 3                 Jailbirds New Orleans      NaN
# 4                          Kota Factory      NaN
# 10  Vendetta: Truth, Lies and The Mafia      NaN
# 14      Crime Stories: India Detectives      NaN
# 15                    Dear White People      NaN
# 17                      Falsa identidad      NaN
# 19                               Jaguar      NaN
# 21               Resurrection: Ertugrul      NaN
# 25                 Love on the Spectrum      NaN

# %%
df['director'] = df['director'].fillna('Not Specified')

# %%
df['director'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['cast'].isnull()][['title', 'cast']].head(10)
# Out:
#                                                 title cast
# 0                                Dick Johnson Is Dead  NaN
# 3                               Jailbirds New Orleans  NaN
# 10                Vendetta: Truth, Lies and The Mafia  NaN
# 14                    Crime Stories: India Detectives  NaN
# 16  Europe's Most Dangerous Man: Otto Skorzeny in ...  NaN
# 20    Monsters Inside: The 24 Faces of Billy Milligan  NaN
# 45                             My Heroes Were Cowboys  NaN
# 66                      Raja Rasoi Aur Anya Kahaniyan  NaN
# 69                     Stories by Rabindranath Tagore  NaN
# 74          The World's Most Amazing Vacation Rentals  NaN

# %%
df['cast'] = df['cast'].fillna('Not Specified')

# %%
df['cast'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['country'].isnull()][['title', 'country']].head(10)
# Out:
#                                                 title country
# 2                                           Ganglands     NaN
# 3                               Jailbirds New Orleans     NaN
# 5                                       Midnight Mass     NaN
# 6                    My Little Pony: A New Generation     NaN
# 10                Vendetta: Truth, Lies and The Mafia     NaN
# 11                                   Bangkok Breaking     NaN
# 13                   Confessions of an Invisible Girl     NaN
# 14                    Crime Stories: India Detectives     NaN
# 16  Europe's Most Dangerous Man: Otto Skorzeny in ...     NaN
# 18                                          Intrusion     NaN

# %%
df['country'] = df['country'].fillna('Not Specified')

# %%
df['country'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['date_added'].isnull()][['title', 'date_added']]
# Out:
#                                             title date_added
# 6066  A Young Doctor's Notebook and Other Stories        NaN
# 6174              Anthony Bourdain: Parts Unknown        NaN
# 6795                                      Frasier        NaN
# 6806                                      Friends        NaN
# 6901                              Gunslinger Girl        NaN
# 7196                                     Kikoriki        NaN
# 7254                          La Familia P. Luche        NaN
# 7406                                        Maron        NaN
# 7847                                 Red vs. Blue        NaN
# 8182                 The Adventures of Figaro Pho        NaN

# %%
df['date_added'] = df['date_added'].fillna('Not Specified')

# %%
df['date_added'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['rating'].isnull()][['title', 'type', 'rating']]
# Out:
#                                                   title     type rating
# 5989  13TH: A Conversation with Oprah Winfrey & Ava ...    Movie    NaN
# 6827                  Gargantia on the Verdurous Planet  TV Show    NaN
# 7312                                       Little Lunch  TV Show    NaN
# 7537                               My Honor Was Loyalty    Movie    NaN

# %%
df['rating'] = df['rating'].fillna('Not Specified')

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['duration'].isnull()][['title', 'type', 'duration']]
# Out:
#                                      title   type duration
# 5541                       Louis C.K. 2017  Movie      NaN
# 5794                 Louis C.K.: Hilarious  Movie      NaN
# 5813  Louis C.K.: Live at the Comedy Store  Movie      NaN

# %%
df['duration'] = df['duration'].fillna('Not Specified')

# %%
df['duration'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df['date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df[['date_added']].head()
# Out:
#   date_added
# 0 2021-09-25
# 1 2021-09-24
# 2 2021-09-24
# 3 2021-09-24
# 4 2021-09-24

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
df['duration'].value_counts().head(20)
# Out:
# duration
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
# 97 min        146
# 93 min        146
# 91 min        144
# 95 min        137
# 96 min        130
# 92 min        129
# 102 min       122
# 98 min        120
# 99 min        118
# 88 min        116
# 101 min       116
# 103 min       114
# 106 min       111
# 100 min       108
# 89 min        106
# Name: count, dtype: int64

# %%
df['duration_number'] = df['duration'].str.extract(r'(\d+)').astype(float)

# %%
df[['duration', 'duration_number']].head(10)
# Out:
#     duration  duration_number
# 0     90 min             90.0
# 1  2 Seasons              2.0
# 2   1 Season              1.0
# 3   1 Season              1.0
# 4  2 Seasons              2.0
# 5   1 Season              1.0
# 6     91 min             91.0
# 7    125 min            125.0
# 8  9 Seasons              9.0
# 9    104 min            104.0

# %%
df['duration_minutes'] = df['duration_number'].where(df['type'] == 'Movie')

# %%
df[['type', 'duration', 'duration_minutes']].head(10)
# Out:
#       type   duration  duration_minutes
# 0    Movie     90 min              90.0
# 1  TV Show  2 Seasons               NaN
# 2  TV Show   1 Season               NaN
# 3  TV Show   1 Season               NaN
# 4  TV Show  2 Seasons               NaN
# 5  TV Show   1 Season               NaN
# 6    Movie     91 min              91.0
# 7    Movie    125 min             125.0
# 8  TV Show  9 Seasons               NaN
# 9    Movie    104 min             104.0

# %%
df['duration_seasons'] = df['duration_number'].where(df['type'] == 'TV Show')

# %%
df[['type', 'duration', 'duration_seasons']].head(10)
# Out:
#       type   duration  duration_seasons
# 0    Movie     90 min               NaN
# 1  TV Show  2 Seasons               2.0
# 2  TV Show   1 Season               1.0
# 3  TV Show   1 Season               1.0
# 4  TV Show  2 Seasons               2.0
# 5  TV Show   1 Season               1.0
# 6    Movie     91 min               NaN
# 7    Movie    125 min               NaN
# 8  TV Show  9 Seasons               9.0
# 9    Movie    104 min               NaN

# %%
df[['type', 'duration', 'duration_number', 'duration_minutes', 'duration_seasons']].head(10)
# Out:
#       type   duration  duration_number  duration_minutes  duration_seasons
# 0    Movie     90 min             90.0              90.0               NaN
# 1  TV Show  2 Seasons              2.0               NaN               2.0
# 2  TV Show   1 Season              1.0               NaN               1.0
# 3  TV Show   1 Season              1.0               NaN               1.0
# 4  TV Show  2 Seasons              2.0               NaN               2.0
# 5  TV Show   1 Season              1.0               NaN               1.0
# 6    Movie     91 min             91.0              91.0               NaN
# 7    Movie    125 min            125.0             125.0               NaN
# 8  TV Show  9 Seasons              9.0               NaN               9.0
# 9    Movie    104 min            104.0             104.0               NaN

# %%
df.drop(columns='duration_number', inplace=True)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'duration_minutes', 'duration_seasons'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# show_id                0
# type                   0
# title                  0
# director               0
# cast                   0
# country                0
# date_added            98
# release_year           0
# rating                 0
# duration               0
# listed_in              0
# description            0
# duration_minutes    2679
# duration_seasons    6131
# dtype: int64

# %%
df[df['date_added'].isnull()][['title', 'date_added']].head(20)
# Out:
#                                             title date_added
# 6066  A Young Doctor's Notebook and Other Stories        NaT
# 6079                              Abnormal Summit        NaT
# 6174              Anthony Bourdain: Parts Unknown        NaT
# 6177                                     忍者ハットリくん        NaT
# 6213                                Bad Education        NaT
# 6279                  Being Mary Jane: The Series        NaT
# 6304                     Big Dreams, Small Spaces        NaT
# 6318                                       Bitten        NaT
# 6357                                 Bondi Rescue        NaT
# 6361                                   Borderline        NaT
# 6368                                  Brain Games        NaT
# 6393                                   Burnistoun        NaT
# 6451                             Chasing Monsters        NaT
# 6456                                       Cheers        NaT
# ...

# %%
df.shape
# Out:
# (8807, 14)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7, 5))

sns.countplot(data=df, x='type')

plt.title('Movies vs TV Shows on Netflix')
plt.xlabel('Content Type')
plt.ylabel('Number of Titles')

plt.show()
